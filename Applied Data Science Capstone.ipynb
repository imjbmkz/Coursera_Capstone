# %% [markdown]
# # Applied Data Science Capstone

# %% [markdown]
# ## **Welcome to my notebook!**
#
# This notebook is intended to work on my Capstone project for the course **Applied Data Science Capstone** in Coursera.

# %% [markdown]
# ### First Peer Graded Assignment: Importing Libraries and Basic Print

# %%
#importing Python libraries

import pandas as pd #import pandas library
import numpy as np #import numpy library

print("Hello Capstone Project Course!") #print message
# Out:
# Hello Capstone Project Course!
